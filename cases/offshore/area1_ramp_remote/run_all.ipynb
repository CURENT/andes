# %% [markdown]
# # Case Descriptions
#
# ## ROCOF based methods w/ remote frequency sensing
#
# 0.4 pu load ramping on Bus 12 in Area 1
#
#  - _Case 1_: No inertia emulation at all
#  - _Case 2_: Power Sharing between areas (VSC 1 and 2 local inertia emulation enabled, VSC 2 dc droop enabled)
#  - _Case 3_: WTG inertia response (VSC 2 inertia emulation, WTGs IE enabled)
#  - _Case 4_: Area power sharing with WTG inertial response (VSC 1 and 2 inertia emulation enabled. Observe inadequate responses from WTGs)
#  - _Case 5_: Adequate inertial response from WTGs (additional frequency information from grid areas)
#
# Load Ramping in Area 1

# %%
# %matplotlib inline

import os

from matplotlib import pyplot

from andes.main import run
from andes.plot import main as andesplot
from andes.plot import read_dat, read_label, do_plot, add_plot

# %%
with  open('case1.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm

ALTER, VSC1_IE2, REP, VSC 1, Ki, 0
ALTER, VSC1_IE2, REP, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, 0
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 0

ALTER, WTG4DC, REP, WTG4 1, Kdc, 0
ALTER, WTG4DC, REP, WTG4 2, Kdc, 0
""")

run(routine='s', case='case1.dm', pert='load12_ramp.py')
run(routine='t', case='case1.dm', pert='load12_ramp.py')
# Out:
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 04:44:06 PM
#
# Parsing input file case1.dm.
# Case file case1.dm parsed in 0.0163 second.
# System models initialized in 0.0109 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0486 second.
# Dynamic models initialized in 0.0042 second.
# Static report written to <case1_out.txt> in 0.0057 second.
#
# Eigenvalue Analysis:
# Report saved.
# System is small-signal stable in the initial neighbourhood.
# Analysis finished in 0.4334 second.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 04:44:07 PM
#
# Parsing input file case1.dm.
# Case file case1.dm parsed in 0.0177 second.
# System models initialized in 0.0109 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0523 second.
# Dynamic models initialized in 0.0090 second.
# Static report written to <case1_out.txt> in 0.0097 second.
#
# Time Domain Simulation:
# Integration Method: Implicit Trapezoidal
# Simulation time: 20
#  (0%) Time = 0.0333s, step = 1, niter = 1
#  (5%) Time = 1.0333s, step = 31, niter = 1
# Load on Bus 12 ramped up by 0.4 pu at t = 2
#  (10%) Time = 2.0333s, step = 61, niter = 3
#  (15%) Time = 3.0333s, step = 91, niter = 3
#  (20%) Time = 4.0333s, step = 121, niter = 3
#  (25%) Time = 5.0333s, step = 151, niter = 3
#  (30%) Time = 6.0333s, step = 181, niter = 3
#  (35%) Time = 7.0333s, step = 211, niter = 3
#  (40%) Time = 8.0333s, step = 241, niter = 3
#  (45%) Time = 9.0333s, step = 271, niter = 3
#  (50%) Time = 10.0333s, step = 301, niter = 3
#  (55%) Time = 11.0333s, step = 331, niter = 3
#  (60%) Time = 12.0333s, step = 361, niter = 3
#  (65%) Time = 13.0333s, step = 391, niter = 3
#  (70%) Time = 14.0333s, step = 421, niter = 3
#  (75%) Time = 15.0333s, step = 451, niter = 3
#  (80%) Time = 16.0333s, step = 481, niter = 3
#  (85%) Time = 17.0333s, step = 511, niter = 3
#  (90%) Time = 18.0333s, step = 541, niter = 3
#  (95%) Time = 19.0333s, step = 571, niter = 3
#  (100%) Time = 20.0000s, step = 600, niter = 3
# Time domain simulation finished in 18.5909 seconds.
# Simulation data dumped in 0.0450 second.

# %%
with  open('case2.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm

ALTER, VSC1_IE2, REP, VSC 1, Ki, -50
ALTER, VSC1_IE2, REP, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, -50
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 10

ALTER, WTG4DC, REP, WTG4 1, Kdc, 0
ALTER, WTG4DC, REP, WTG4 2, Kdc, 0
""")
run(routine='s', case='case2.dm', pert='load12_ramp.py')
run(routine='t', case='case2.dm', pert='load12_ramp.py')
# Out:
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 04:44:26 PM
#
# Parsing input file case2.dm.
# Case file case2.dm parsed in 0.0264 second.
# System models initialized in 0.0152 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0358 second.
# Dynamic models initialized in 0.0104 second.
# Static report written to <case2_out.txt> in 0.0146 second.
#
# Eigenvalue Analysis:
# Report saved.
# System is small-signal stable in the initial neighbourhood.
# Analysis finished in 0.3981 second.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 04:44:26 PM
#
# Parsing input file case2.dm.
# Case file case2.dm parsed in 0.0157 second.
# System models initialized in 0.0162 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0423 second.
# Dynamic models initialized in 0.0105 second.
# Static report written to <case2_out.txt> in 0.0122 second.
#
# Time Domain Simulation:
# Integration Method: Implicit Trapezoidal
# Simulation time: 20
#  (0%) Time = 0.0333s, step = 1, niter = 1
#  (5%) Time = 1.0333s, step = 31, niter = 1
# Load on Bus 12 ramped up by 0.4 pu at t = 2
#  (10%) Time = 2.0333s, step = 61, niter = 3
#  (15%) Time = 3.0333s, step = 91, niter = 3
#  (20%) Time = 4.0333s, step = 121, niter = 3
#  (25%) Time = 5.0333s, step = 151, niter = 3
#  (30%) Time = 6.0333s, step = 181, niter = 3
#  (35%) Time = 7.0333s, step = 211, niter = 3
#  (40%) Time = 8.0333s, step = 241, niter = 3
#  (45%) Time = 9.0333s, step = 271, niter = 3
#  (50%) Time = 10.0333s, step = 301, niter = 3
#  (55%) Time = 11.0333s, step = 331, niter = 3
#  (60%) Time = 12.0333s, step = 361, niter = 3
#  (65%) Time = 13.0333s, step = 391, niter = 3
#  (70%) Time = 14.0333s, step = 421, niter = 3
#  (75%) Time = 15.0333s, step = 451, niter = 3
#  (80%) Time = 16.0333s, step = 481, niter = 3
#  (85%) Time = 17.0333s, step = 511, niter = 3
#  (90%) Time = 18.0333s, step = 541, niter = 3
#  (95%) Time = 19.0333s, step = 571, niter = 3
#  (100%) Time = 20.0000s, step = 600, niter = 3
# Time domain simulation finished in 21.3495 seconds.
# Simulation data dumped in 0.0564 second.

# %%
with  open('case3.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm

ALTER, VSC1_IE2, REP, VSC 1, Ki, -50
ALTER, VSC1_IE2, REP, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, 0
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 0

ALTER, WTG4DC, REP, WTG4 1, Kdc, 10
ALTER, WTG4DC, REP, WTG4 2, Kdc, 10
""")

run(routine='s', case='case3.dm', pert='load12_ramp.py')
run(routine='t', case='case3.dm', pert='load12_ramp.py')
# Out:
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 04:52:01 PM
#
# Parsing input file case3.dm.
# Case file case3.dm parsed in 0.0172 second.
# System models initialized in 0.0054 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0857 second.
# Dynamic models initialized in 0.0131 second.
# Static report written to <case3_out.txt> in 0.0154 second.
#
# Eigenvalue Analysis:
# Report saved.
# System is small-signal stable in the initial neighbourhood.
# Analysis finished in 0.3717 second.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 04:52:02 PM
#
# Parsing input file case3.dm.
# Case file case3.dm parsed in 0.0138 second.
# System models initialized in 0.0151 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0540 second.
# Dynamic models initialized in 0.0085 second.
# Static report written to <case3_out.txt> in 0.0107 second.
#
# Time Domain Simulation:
# Integration Method: Implicit Trapezoidal
# Simulation time: 20
#  (0%) Time = 0.0333s, step = 1, niter = 1
#  (5%) Time = 1.0333s, step = 31, niter = 1
# Load on Bus 12 ramped up by 0.4 pu at t = 2
#  (10%) Time = 2.0333s, step = 61, niter = 3
#  (15%) Time = 3.0292s, step = 103, niter = 7
#  (20%) Time = 4.0283s, step = 185, niter = 7
#  (25%) Time = 5.0301s, step = 219, niter = 7
#  (30%) Time = 6.0279s, step = 250, niter = 5
#  (35%) Time = 7.0279s, step = 280, niter = 4
#  (40%) Time = 8.0279s, step = 310, niter = 6
#  (45%) Time = 9.0279s, step = 340, niter = 5
#  (50%) Time = 10.0279s, step = 370, niter = 5
#  (55%) Time = 11.0279s, step = 400, niter = 5
#  (60%) Time = 12.0279s, step = 430, niter = 4
#  (65%) Time = 13.0279s, step = 460, niter = 4
#  (70%) Time = 14.0279s, step = 490, niter = 4
#  (75%) Time = 15.0279s, step = 520, niter = 4
#  (80%) Time = 16.0279s, step = 550, niter = 3
#  (85%) Time = 17.0279s, step = 580, niter = 3
#  (90%) Time = 18.0279s, step = 610, niter = 3
#  (95%) Time = 19.0279s, step = 640, niter = 3
#  (100%) Time = 20.0000s, step = 670, niter = 3
# Time domain simulation finished in 34.0674 seconds.
# Simulation data dumped in 0.0745 second.

# %%
with  open('case4.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm


ALTER, VSC1_IE2, REP, VSC 1, Ki, -50
ALTER, VSC1_IE2, REP, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, -50
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 10

ALTER, WTG4DC, REP, WTG4 1, Kdc, 10
ALTER, WTG4DC, REP, WTG4 2, Kdc, 10
""")
run(routine='s', case='case4.dm', pert='load12_ramp.py')
run(routine='t', case='case4.dm', pert='load12_ramp.py')
# Out:
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 04:45:25 PM
#
# Parsing input file case4.dm.
# Case file case4.dm parsed in 0.0174 second.
# System models initialized in 0.0128 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0340 second.
# Dynamic models initialized in 0.0060 second.
# Static report written to <case4_out.txt> in 0.0118 second.
#
# Eigenvalue Analysis:
# Report saved.
# System is small-signal stable in the initial neighbourhood.
# Analysis finished in 0.4321 second.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 04:45:26 PM
#
# Parsing input file case4.dm.
# Case file case4.dm parsed in 0.0183 second.
# System models initialized in 0.0100 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0674 second.
# Dynamic models initialized in 0.0047 second.
# Static report written to <case4_out.txt> in 0.0073 second.
#
# Time Domain Simulation:
# Integration Method: Implicit Trapezoidal
# Simulation time: 20
#  (0%) Time = 0.0333s, step = 1, niter = 1
#  (5%) Time = 1.0333s, step = 31, niter = 1
# Load on Bus 12 ramped up by 0.4 pu at t = 2
#  (10%) Time = 2.0333s, step = 61, niter = 3
#  (15%) Time = 3.0333s, step = 91, niter = 5
#  (20%) Time = 4.0333s, step = 121, niter = 3
#  (25%) Time = 5.0333s, step = 151, niter = 5
#  (30%) Time = 6.0333s, step = 181, niter = 5
#  (35%) Time = 7.0333s, step = 211, niter = 3
#  (40%) Time = 8.0333s, step = 241, niter = 3
#  (45%) Time = 9.0333s, step = 271, niter = 3
#  (50%) Time = 10.0333s, step = 301, niter = 3
#  (55%) Time = 11.0333s, step = 331, niter = 3
#  (60%) Time = 12.0333s, step = 361, niter = 3
#  (65%) Time = 13.0333s, step = 391, niter = 3
#  (70%) Time = 14.0333s, step = 421, niter = 3
#  (75%) Time = 15.0333s, step = 451, niter = 3
#  (80%) Time = 16.0333s, step = 481, niter = 3
#  (85%) Time = 17.0333s, step = 511, niter = 3
#  (90%) Time = 18.0333s, step = 541, niter = 3
#  (95%) Time = 19.0333s, step = 571, niter = 3
#  (100%) Time = 20.0000s, step = 600, niter = 3
# Time domain simulation finished in 25.8785 seconds.
# Simulation data dumped in 0.0636 second.
