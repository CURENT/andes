# %% [markdown]
# # Case Descriptions
#
# ## ROCOF based methods w/ remote frequency sensing
#
# 0.4 pu load ramping on Bus 12 in Area 1
#
#  - _Case 1_: No inertia emulation at all
#  - _Case 2_: Power Sharing between areas (VSC 1 and 2 local inertia emulation enabled, VSC 2 dc droop enabled)
#  - _Case 3_: WTG inertia response (VSC 2 inertia emulation, WTGs IE enabled)
#  - _Case 4_: Area power sharing with WTG inertial response (VSC 1 and 2 inertia emulation enabled. Observe inadequate responses from WTGs)
#  - _Case 5_: Adequate inertial response from WTGs (additional frequency information from grid areas)
#
# Load Ramping in Area 1

# %%
# %matplotlib inline

import os

from matplotlib import pyplot

from andes.main import run
from andes.plot import main as andesplot
from andes.plot import read_dat, read_label, do_plot, add_plot

# %%
with  open('case1.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm

ALTER, VSC1_IE2, REP, VSC 1, Ki, 0
ALTER, VSC1_IE2, REP, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, 0
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 0

ALTER, WTG4DC, REP, WTG4 1, Kdc, 0
ALTER, WTG4DC, REP, WTG4 2, Kdc, 0
""")

run(routine='s', case='case1.dm', pert='load12_ramp.py')
run(routine='t', case='case1.dm', pert='load12_ramp.py')
# Out:
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 01:58:04 PM
#
# Parsing input file case1.dm.
# Case file case1.dm parsed in 0.0143 second.
# System models initialized in 0.0095 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0539 second.
# Dynamic models initialized in 0.0099 second.
# Static report written to <case1_out.txt> in 0.0095 second.
#
# Eigenvalue Analysis:
# Report saved.
# System is small-signal stable in the initial neighbourhood.
# Analysis finished in 0.3187 second.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 01:58:04 PM
#
# Parsing input file case1.dm.
# Case file case1.dm parsed in 0.0144 second.
# System models initialized in 0.0062 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0440 second.
# Dynamic models initialized in 0.0055 second.
# Static report written to <case1_out.txt> in 0.0101 second.
#
# Time Domain Simulation:
# Integration Method: Implicit Trapezoidal
# Simulation time: 20
#  (0%) Time = 0.0333s, step = 2, niter = 1
#  (5%) Time = 1.0333s, step = 62, niter = 1
# Load on Bus 12 ramped up by 0.4 pu at t = 2
#  (10%) Time = 2.0333s, step = 122, niter = 3
#  (15%) Time = 3.0333s, step = 182, niter = 3
#  (20%) Time = 4.0333s, step = 242, niter = 3
#  (25%) Time = 5.0333s, step = 302, niter = 3
#  (30%) Time = 6.0333s, step = 362, niter = 3
#  (35%) Time = 7.0333s, step = 422, niter = 3
#  (40%) Time = 8.0333s, step = 482, niter = 3
#  (45%) Time = 9.0333s, step = 542, niter = 3
#  (50%) Time = 10.0333s, step = 602, niter = 3
#  (55%) Time = 11.0333s, step = 662, niter = 3
#  (60%) Time = 12.0333s, step = 722, niter = 3
#  (65%) Time = 13.0333s, step = 782, niter = 3
#  (70%) Time = 14.0333s, step = 842, niter = 3
#  (75%) Time = 15.0333s, step = 902, niter = 3
#  (80%) Time = 16.0333s, step = 962, niter = 3
#  (85%) Time = 17.0333s, step = 1022, niter = 3
#  (90%) Time = 18.0333s, step = 1082, niter = 3
#  (95%) Time = 19.0333s, step = 1142, niter = 3
#  (100%) Time = 20.0000s, step = 1200, niter = 3
# Time domain simulation finished in 41.7037 seconds.
# Simulation data dumped in 0.1047 second.

# %%
with  open('case2.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm

ALTER, VSC1_IE2, REP, VSC 1, Ki, -50
ALTER, VSC1_IE2, REP, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, -50
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 10

ALTER, WTG4DC, REP, WTG4 1, Kdc, 0
ALTER, WTG4DC, REP, WTG4 2, Kdc, 0
""")
run(routine='s', case='case2.dm', pert='load12_ramp.py')
run(routine='t', case='case2.dm', pert='load12_ramp.py')
# Out:
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 02:08:10 PM
#
# Parsing input file case2.dm.
# Case file case2.dm parsed in 0.0180 second.
# System models initialized in 0.0141 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0421 second.
# Dynamic models initialized in 0.0043 second.
# Static report written to <case2_out.txt> in 0.0100 second.
#
# Eigenvalue Analysis:
# Report saved.
# System is small-signal stable in the initial neighbourhood.
# Analysis finished in 0.3429 second.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 02:08:10 PM
#
# Parsing input file case2.dm.
# Case file case2.dm parsed in 0.0153 second.
# System models initialized in 0.0126 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0396 second.
# Dynamic models initialized in 0.0129 second.
# Static report written to <case2_out.txt> in 0.0085 second.
#
# Time Domain Simulation:
# Integration Method: Implicit Trapezoidal
# Simulation time: 20
#  (0%) Time = 0.0333s, step = 2, niter = 1
#  (5%) Time = 1.0333s, step = 62, niter = 1
# Load on Bus 12 ramped up by 0.4 pu at t = 2
#  (10%) Time = 2.0333s, step = 122, niter = 3
#  (15%) Time = 3.0333s, step = 182, niter = 3
#  (20%) Time = 4.0333s, step = 242, niter = 3
#  (25%) Time = 5.0333s, step = 302, niter = 3
#  (30%) Time = 6.0333s, step = 362, niter = 3
#  (35%) Time = 7.0333s, step = 422, niter = 3
#  (40%) Time = 8.0333s, step = 482, niter = 3
#  (45%) Time = 9.0333s, step = 542, niter = 3
#  (50%) Time = 10.0333s, step = 602, niter = 3
#  (55%) Time = 11.0333s, step = 662, niter = 3
#  (60%) Time = 12.0333s, step = 722, niter = 3
#  (65%) Time = 13.0333s, step = 782, niter = 3
#  (70%) Time = 14.0333s, step = 842, niter = 3
#  (75%) Time = 15.0333s, step = 902, niter = 3
#  (80%) Time = 16.0333s, step = 962, niter = 3
#  (85%) Time = 17.0333s, step = 1022, niter = 3
#  (90%) Time = 18.0333s, step = 1082, niter = 3
#  (95%) Time = 19.0333s, step = 1142, niter = 3
#  (100%) Time = 20.0000s, step = 1200, niter = 3
# Time domain simulation finished in 36.9787 seconds.
# Simulation data dumped in 0.0918 second.

# %%
with  open('case3.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm


ALTER, VSC1_IE2, REP, VSC 1, Ki, -50
ALTER, VSC1_IE2, MUL, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, 0
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 0

ALTER, WTG4DC, REP, WTG4 1, Kdc, 10
ALTER, WTG4DC, REP, WTG4 2, Kdc, 10
""")

run(routine='s', case='case3.dm', pert='load12_ramp.py')
run(routine='t', case='case3.dm', pert='load12_ramp.py')
# Out:
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 02:01:35 PM
#
# Parsing input file case3.dm.
# Case file case3.dm parsed in 0.0177 second.
# System models initialized in 0.0178 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0384 second.
# Dynamic models initialized in 0.0081 second.
# Static report written to <case3_out.txt> in 0.0113 second.
#
# Eigenvalue Analysis:
# Report saved.
# System is small-signal stable in the initial neighbourhood.
# Analysis finished in 0.3701 second.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 02:01:35 PM
#
# Parsing input file case3.dm.
# Case file case3.dm parsed in 0.0163 second.
# System models initialized in 0.0148 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0282 second.
# Dynamic models initialized in 0.0058 second.
# Static report written to <case3_out.txt> in 0.0071 second.
#
# Time Domain Simulation:
# Integration Method: Implicit Trapezoidal
# Simulation time: 20
#  (0%) Time = 0.0333s, step = 2, niter = 1
#  (5%) Time = 1.0333s, step = 62, niter = 1
# Load on Bus 12 ramped up by 0.4 pu at t = 2
#  (10%) Time = 2.0333s, step = 122, niter = 3
#  (15%) Time = 3.0242s, step = 184, niter = 7
#  (20%) Time = 4.0303s, step = 267, niter = 7
#  (25%) Time = 5.0294s, step = 327, niter = 5
#  (30%) Time = 6.0294s, step = 387, niter = 4
#  (35%) Time = 7.0294s, step = 447, niter = 4
#  (40%) Time = 8.0294s, step = 507, niter = 4
#  (45%) Time = 9.0294s, step = 567, niter = 4
#  (50%) Time = 10.0294s, step = 627, niter = 3
#  (55%) Time = 11.0294s, step = 687, niter = 3
#  (60%) Time = 12.0294s, step = 747, niter = 3
#  (65%) Time = 13.0294s, step = 807, niter = 3
#  (70%) Time = 14.0294s, step = 867, niter = 3
#  (75%) Time = 15.0294s, step = 927, niter = 3
#  (80%) Time = 16.0294s, step = 987, niter = 3
#  (85%) Time = 17.0294s, step = 1047, niter = 3
#  (90%) Time = 18.0294s, step = 1107, niter = 3
#  (95%) Time = 19.0294s, step = 1167, niter = 3
#  (100%) Time = 20.0000s, step = 1226, niter = 3
# Time domain simulation finished in 44.1146 seconds.
# Simulation data dumped in 0.1016 second.

# %%
with  open('case4.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm


ALTER, VSC1_IE2, REP, VSC 1, Ki, -50
ALTER, VSC1_IE2, REP, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, -50
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 10

ALTER, WTG4DC, REP, WTG4 1, Kdc, 10
ALTER, WTG4DC, REP, WTG4 2, Kdc, 10
""")
run(routine='s', case='case4.dm', pert='load12_ramp.py')
run(routine='t', case='case4.dm', pert='load12_ramp.py')
# Out:
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 02:06:55 PM
#
# Parsing input file case4.dm.
# Case file case4.dm parsed in 0.0213 second.
# System models initialized in 0.0102 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0532 second.
# Dynamic models initialized in 0.0134 second.
# Static report written to <case4_out.txt> in 0.0095 second.
#
# Eigenvalue Analysis:
# Report saved.
# System is small-signal stable in the initial neighbourhood.
# Analysis finished in 0.3568 second.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 02:06:56 PM
#
# Parsing input file case4.dm.
# Case file case4.dm parsed in 0.0144 second.
# System models initialized in 0.0080 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0256 second.
# Dynamic models initialized in 0.0070 second.
# Static report written to <case4_out.txt> in 0.0056 second.
#
# Time Domain Simulation:
# Integration Method: Implicit Trapezoidal
# Simulation time: 20
#  (0%) Time = 0.0333s, step = 2, niter = 1
#  (5%) Time = 1.0333s, step = 62, niter = 1
# Load on Bus 12 ramped up by 0.4 pu at t = 2
#  (10%) Time = 2.0333s, step = 122, niter = 3
#  (15%) Time = 3.0333s, step = 182, niter = 4
#  (20%) Time = 4.0333s, step = 242, niter = 3
#  (25%) Time = 5.0333s, step = 302, niter = 4
#  (30%) Time = 6.0333s, step = 362, niter = 4
#  (35%) Time = 7.0333s, step = 422, niter = 3
#  (40%) Time = 8.0333s, step = 482, niter = 3
#  (45%) Time = 9.0333s, step = 542, niter = 3
#  (50%) Time = 10.0333s, step = 602, niter = 3
#  (55%) Time = 11.0333s, step = 662, niter = 3
#  (60%) Time = 12.0333s, step = 722, niter = 3
#  (65%) Time = 13.0333s, step = 782, niter = 3
#  (70%) Time = 14.0333s, step = 842, niter = 3
#  (75%) Time = 15.0333s, step = 902, niter = 3
#  (80%) Time = 16.0333s, step = 962, niter = 3
#  (85%) Time = 17.0333s, step = 1022, niter = 3
#  (90%) Time = 18.0333s, step = 1082, niter = 3
#  (95%) Time = 19.0333s, step = 1142, niter = 3
#  (100%) Time = 20.0000s, step = 1200, niter = 3
# Time domain simulation finished in 37.9334 seconds.
# Simulation data dumped in 0.1117 second.
