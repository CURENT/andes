# %%
# %matplotlib inline

import os

from matplotlib import pyplot

from andes.main import run
from andes.plot import main as andesplot
from andes.plot import read_dat, read_label, do_plot, add_plot


tds = {
    'case': os.path.abspath('./ieee14_gentrip.dm'),
    'pert': 'gen2_trip.py',
    'routine': 't',
    }

run(**tds)
# Out:
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     06/22/2018 04:58:07 PM
#
# Parsing input file ieee14_gentrip.dm.
# Case file ieee14_gentrip.dm parsed in 0.0327 second.
# System models initialized in 0.0138 second.
#
# System is interconnected.
#
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.5621880
# Iter   2.  Max. Mismatch = 0.1435745
# Iter   3.  Max. Mismatch = 0.0021439
# Iter   4.  Max. Mismatch = 0.0000933
# Iter   5.  Max. Mismatch = 0.0000000
# Power flow converged in 0.0516 second.
# Dynamic models initialized in 0.0072 second.
# Static report written to <ieee14_gentrip_out.txt> in 0.0054 second.
#
# Time Domain Simulation:
# Integration Method: Implicit Trapezoidal
# Simulation time: 20
# * Warning: Pert file is discarded due to import errors.
#  (0%) Time = 0.0333s, step = 1, niter = 1
#  (5%) Time = 1.0333s, step = 31, niter = 1
#  (10%) Time = 2.0333s, step = 61, niter = 1
#  (15%) Time = 3.0333s, step = 91, niter = 1
#  (20%) Time = 4.0333s, step = 121, niter = 1
#  (25%) Time = 5.0333s, step = 151, niter = 1
#  (30%) Time = 6.0333s, step = 181, niter = 1
#  (35%) Time = 7.0333s, step = 211, niter = 1
#  (40%) Time = 8.0333s, step = 241, niter = 1
#  (45%) Time = 9.0333s, step = 271, niter = 1
#  (50%) Time = 10.0333s, step = 301, niter = 1
#  (55%) Time = 11.0333s, step = 331, niter = 1
#  (60%) Time = 12.0333s, step = 361, niter = 1
#  (65%) Time = 13.0333s, step = 391, niter = 1
#  (70%) Time = 14.0333s, step = 421, niter = 1
#  (75%) Time = 15.0333s, step = 451, niter = 1
#  (80%) Time = 16.0333s, step = 481, niter = 1
#  (85%) Time = 17.0333s, step = 511, niter = 1
#  (90%) Time = 18.0333s, step = 541, niter = 1
#  (95%) Time = 19.0333s, step = 571, niter = 1
#  (100%) Time = 20.0000s, step = 600, niter = 1
# Time domain simulation finished in 3.2455 seconds.
# Simulation data dumped in 0.0400 second.

# %%
p_VSC = {'datfile': ['ieee14_gentrip_out.dat'],
       'x': [0],
       'y': [266, 276],
       }

andesplot(cli=False, **p_VSC)

V_AC = {'datfile': ['ieee14_gentrip_out.dat'],
       'x': [0],
       'y': [145, 146],
       }
andesplot(cli=False, **V_AC)

# %%
x_idx = [0]
y_idx = [10]

xv, yv = read_dat('ieee14_gentrip_out.dat', x_idx, y_idx)
xl, yl = read_label('ieee14_gentrip_out.lst', x_idx, y_idx)

fig, ax = do_plot(xv, yv, xl, yl, {})

# %%
y_idx2 = [50]

xv2, yv2 = read_dat('ieee14_gentrip_out.dat', x_idx, y_idx2)
xl2, yl2 = read_label('ieee14_gentrip_out.lst', x_idx, y_idx2)

add_plot(xv2, yv2, xl2, yl2, fig, ax, LATEX=True)

ax.set_ylim([0.995, 1.002])
fig
