# %%
# %matplotlib inline

import os

from matplotlib import pyplot

from andes.main import run
from andes.plot import main as andesplot
from andes.plot import read_dat, read_label, do_plot, add_plot


tds = {
    'case': os.path.abspath('./ieee14_loadramp.dm'),
    'pert': 'load12_ramp.py',
    }

run(routine='s', **tds)
run(routine='t', **tds)
# Out:
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     06/24/2018 03:06:17 PM
#
# Parsing input file ieee14_loadramp.dm.
# Case file ieee14_loadramp.dm parsed in 0.0142 second.
# System models initialized in 0.0082 second.
#
# System is interconnected.
#
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.5621880
# Iter   2.  Max. Mismatch = 0.1435745
# Iter   3.  Max. Mismatch = 0.0021439
# Iter   4.  Max. Mismatch = 0.0000933
# Iter   5.  Max. Mismatch = 0.0000000
# Power flow converged in 0.0261 second.
# Dynamic models initialized in 0.0066 second.
# Static report written to <ieee14_loadramp_out.txt> in 0.0069 second.
#
# Eigenvalue Analysis:
# Report saved.
# System is small-signal stable in the initial neighbourhood.
# Analysis finished in 0.2439 second.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     06/24/2018 03:06:17 PM
#
# Parsing input file ieee14_loadramp.dm.
# Case file ieee14_loadramp.dm parsed in 0.0116 second.
# System models initialized in 0.0099 second.
#
# System is interconnected.
#
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.5621880
# Iter   2.  Max. Mismatch = 0.1435745
# Iter   3.  Max. Mismatch = 0.0021439
# Iter   4.  Max. Mismatch = 0.0000933
# Iter   5.  Max. Mismatch = 0.0000000
# Power flow converged in 0.0243 second.
# Dynamic models initialized in 0.0088 second.
# Static report written to <ieee14_loadramp_out.txt> in 0.0077 second.
#
# Time Domain Simulation:
# Integration Method: Implicit Trapezoidal
# Simulation time: 20
#  (0%) Time = 0.0333s, step = 1, niter = 1
#  (5%) Time = 1.0333s, step = 31, niter = 1
# Load on Bus 12 ramped up by 0.4 pu at t = 2
#  (10%) Time = 2.0333s, step = 61, niter = 3
#  (15%) Time = 3.0333s, step = 91, niter = 3
#  (20%) Time = 4.0333s, step = 121, niter = 3
#  (25%) Time = 5.0333s, step = 151, niter = 3
#  (30%) Time = 6.0333s, step = 181, niter = 3
#  (35%) Time = 7.0333s, step = 211, niter = 3
#  (40%) Time = 8.0333s, step = 241, niter = 2
#  (45%) Time = 9.0333s, step = 271, niter = 2
#  (50%) Time = 10.0333s, step = 301, niter = 2
#  (55%) Time = 11.0333s, step = 331, niter = 2
#  (60%) Time = 12.0333s, step = 361, niter = 2
#  (65%) Time = 13.0333s, step = 391, niter = 2
#  (70%) Time = 14.0333s, step = 421, niter = 2
#  (75%) Time = 15.0333s, step = 451, niter = 2
#  (80%) Time = 16.0333s, step = 481, niter = 2
#  (85%) Time = 17.0333s, step = 511, niter = 2
#  (90%) Time = 18.0333s, step = 541, niter = 2
#  (95%) Time = 19.0333s, step = 571, niter = 2
#  (100%) Time = 20.0000s, step = 600, niter = 2
# Time domain simulation finished in 7.7922 seconds.
# Simulation data dumped in 0.0383 second.

# %%
p_VSC = {'datfile': ['ieee14_loadramp_out.dat'],
       'x': [0],
       'y': [266, 276],
       }

andesplot(cli=False, **p_VSC)

V_AC = {'datfile': ['ieee14_loadramp_out.dat'],
       'x': [0],
       'y': [145, 146],
       }
andesplot(cli=False, **V_AC)


Freq_1314 = {'datfile': ['ieee14_loadramp_out.dat'],
            'x': [0],
            'y': [34, 36],
            'ytimes': '60',
            }
andesplot(cli=False, **Freq_1314)

# %%
x_idx = [0]
y_idx = [10]

xv, yv = read_dat('ieee14_loadramp_out.dat', x_idx, y_idx)
xl, yl = read_label('ieee14_loadramp_out.lst', x_idx, y_idx)

fig, ax = do_plot(xv, yv, xl, yl, {})

# %%
y_idx2 = [50]

xv2, yv2 = read_dat('ieee14_loadramp_out.dat', x_idx, y_idx2)
xl2, yl2 = read_label('ieee14_loadramp_out.lst', x_idx, y_idx2)

add_plot(xv2, yv2, xl2, yl2, fig, ax, LATEX=True)

ax.set_ylim([0.995, 1.002])
fig
