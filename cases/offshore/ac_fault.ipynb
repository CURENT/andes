# %%
# %matplotlib inline

import os

from matplotlib import pyplot

from andes.main import run
from andes.plot import main as andesplot
from andes.plot import read_dat, read_label, do_plot, add_plot


tds = {
    'case': os.path.abspath('./ieee14.dm'),
    'routine': 't',
    }

run(**tds)
# Out:
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     06/22/2018 04:57:24 PM
#
# Parsing input file ieee14.dm.
# Case file ieee14.dm parsed in 0.0113 second.
# System models initialized in 0.0133 second.
#
# System is interconnected.
#
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.5621880
# Iter   2.  Max. Mismatch = 0.1435745
# Iter   3.  Max. Mismatch = 0.0021439
# Iter   4.  Max. Mismatch = 0.0000933
# Iter   5.  Max. Mismatch = 0.0000000
# Power flow converged in 0.0220 second.
# Dynamic models initialized in 0.0107 second.
# Static report written to <ieee14_out.txt> in 0.0095 second.
#
# Time Domain Simulation:
# Integration Method: Implicit Trapezoidal
# Simulation time: 20
#  (0%) Time = 0.0333s, step = 1, niter = 1
#  (5%) Time = 1.0333s, step = 31, niter = 1
#
#  <Fault> Applying fault on Bus <3.0> at t=2.0.
#  (10%) Time = 2.0221s, step = 71, niter = 3
#
#  <Fault> Clearing fault on Bus <3.0> at t=2.1.
#  (15%) Time = 3.0364s, step = 130, niter = 3
#  (20%) Time = 4.0364s, step = 160, niter = 3
#  (25%) Time = 5.0364s, step = 190, niter = 3
#  (30%) Time = 6.0364s, step = 220, niter = 2
#  (35%) Time = 7.0364s, step = 250, niter = 2
#  (40%) Time = 8.0364s, step = 280, niter = 2
#  (45%) Time = 9.0364s, step = 310, niter = 2
#  (50%) Time = 10.0364s, step = 340, niter = 2
#  (55%) Time = 11.0364s, step = 370, niter = 2
#  (60%) Time = 12.0364s, step = 400, niter = 2
#  (65%) Time = 13.0364s, step = 430, niter = 2
#  (70%) Time = 14.0364s, step = 460, niter = 2
#  (75%) Time = 15.0364s, step = 490, niter = 2
#  (80%) Time = 16.0364s, step = 520, niter = 2
#  (85%) Time = 17.0364s, step = 550, niter = 2
#  (90%) Time = 18.0364s, step = 580, niter = 2
#  (95%) Time = 19.0364s, step = 610, niter = 2
#  (100%) Time = 20.0000s, step = 639, niter = 2
# Time domain simulation finished in 7.0929 seconds.
# Simulation data dumped in 0.0614 second.

# %%
p_VSC = {'datfile': ['ieee14_out.dat'],
       'x': [0],
       'y': [266, 276],
       }

andesplot(cli=False, **p_VSC)

V_AC = {'datfile': ['ieee14_out.dat'],
       'x': [0],
       'y': [145, 146],
       }
andesplot(cli=False, **V_AC)

# %%
x_idx = [0]
y_idx = [10]
y_idx2 = [50]

xv, yv = read_dat('ieee14_out.dat', x_idx, y_idx)
xl, yl = read_label('ieee14_out.lst', x_idx, y_idx)

fig, ax = do_plot(xv, yv, xl, yl, {})

# %%
xv2, yv2 = read_dat('ieee14_out.dat', x_idx, y_idx2)
xl2, yl2 = read_label('ieee14_out.lst', x_idx, y_idx2)

add_plot(xv2, yv2, xl2, yl2, fig, ax, LATEX=True)

ax.set_ylim([0.9975, 1.0025])
fig
