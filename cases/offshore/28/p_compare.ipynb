# %%
# %matplotlib inline

import os

from matplotlib import pyplot

from andes.main import run
from andes.plot import main as andesplot
from andes.plot import read_dat, read_label, do_plot, add_plot

fault_dat = ['ieee14_out.dat']
fault_lst = ['ieee14_out.lst']

gentrip_dat = ['ieee14_gentrip_out.dat']
gentrip_lst = ['ieee14_gentrip_out.dat']

loadramp_dat = ['ieee14_loadramp_out.dat']
loadramp_lst = ['ieee14_loadramp_out.dat']


p_VSC = {'x': [0],
             'y': [266, 276],
             'ytimes': 100,
             'ylabel': 'Active Power [MW]'
            }

andesplot(cli=False, datfile=fault_dat, **p_VSC)

andesplot(cli=False, datfile=gentrip_dat, **p_VSC)

andesplot(cli=False, datfile=loadramp_dat, **p_VSC)

# %%
# %matplotlib inline

import os

from matplotlib import pyplot

from andes.main import run
from andes.plot import main as andesplot
from andes.plot import read_dat, read_label, do_plot, add_plot

fault_dat = ['ieee14_out.dat']
fault_lst = ['ieee14_out.lst']

gentrip_dat = ['ieee14_gentrip_out.dat']
gentrip_lst = ['ieee14_gentrip_out.dat']

loadramp_dat = ['ieee14_loadramp_out.dat']
loadramp_lst = ['ieee14_loadramp_out.dat']


p_VSC = {'x': [0],
             'y': [266, 276],
             'ytimes': 100,
             'ylabel': 'Active Power [MW]'
            }

andesplot(cli=False, datfile=fault_dat, **p_VSC)

andesplot(cli=False, datfile=gentrip_dat, **p_VSC)

andesplot(cli=False, datfile=loadramp_dat, **p_VSC)
