# %% [markdown]
# # Case Descriptions
#
# ## ROCOF based methods
#
# 0.4 pu load ramping on Bus 12 in Area 2
#
#  - _Case 1_: No inertia emulation at all
#  - _Case 2_: Power Sharing between areas (VSC 1 and 2 local inertia emulation enabled, VSC 2 dc droop enabled)
#  - _Case 3_: WTG inertia response (VSC 2 inertia emulation, WTGs IE enabled)
#  - _Case 4_: Area power sharing with WTG inertial response (VSC 1 and 2 inertia emulation enabled. Observe inadequate responses from WTGs)
#  - _Case 5_: Adequate inertial response from WTGs (additional frequency information from grid areas)
#
# Load Ramping in Area 2

# %%
with  open('case1.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm

ALTER, VSC1_IE2, REP, VSC 1, Ki, 0
ALTER, VSC1_IE2, REP, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, 0
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 0

ALTER, WTG4DC, REP, WTG4 1, Kdc, 0
ALTER, WTG4DC, REP, WTG4 2, Kdc, 0
""")

with  open('case2.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm

ALTER, VSC1_IE2, REP, VSC 1, Ki, 50
ALTER, VSC1_IE2, REP, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, 50
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 10

ALTER, WTG4DC, REP, WTG4 1, Kdc, 0
ALTER, WTG4DC, REP, WTG4 2, Kdc, 0
""")

with  open('case3.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm

ALTER, VSC1_IE2, REP, VSC 1, Ki, -0
ALTER, VSC1_IE2, MUL, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, 50
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 10

ALTER, WTG4DC, REP, WTG4 1, Kdc, 10
ALTER, WTG4DC, REP, WTG4 2, Kdc, 10
""")

with  open('case4.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm

ALTER, VSC1_IE2, REP, VSC 1, Ki, 50
ALTER, VSC1_IE2, REP, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, 50
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 10

ALTER, WTG4DC, REP, WTG4 1, Kdc, 10
ALTER, WTG4DC, REP, WTG4 2, Kdc, 10
""")

# %%
# %matplotlib inline

import os

from matplotlib import pyplot
import andes
from andes.main import run
from andes.plot import main as andesplot
from andes.plot import read_dat, read_label, do_plot, add_plot
import logging

andes.main.config_logger(log_file=None, stream_level=logging.DEBUG)

# %%
run(routine=['tds'], case='case1.dm', pert='load212_ramp.py')
run(routine=['tds'], case='case2.dm', pert='load212_ramp.py')
run(routine=['tds'], case='case3.dm', pert='load212_ramp.py')
run(routine=['tds'], case='case4.dm', pert='load212_ramp.py')
# Out:
# cvxoptklu import error. Fall back to umfpack
# Found config file at /Users/hcui7/.andes/andes.conf.
# Loaded config file from /Users/hcui7/.andes/andes.conf.
# /usr/local/miniconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# Input format guessed as dome.
# Parsing input file <case1.dm>
# Parsing include file <ieee28.dm>
# Imported model <vsc.VSC>.
# Imported model <vsc.VSC1_IE2>.
# Imported model <windturbine.WTG4DC>.
# Imported model <wind.ConstWind>.
# Parsing of include file <ieee28.dm> completed.
# Case file case1.dm parsed in 0.0252 second.
# -> Power flow study: NR method, non-flat start
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
# Power flow initialized in 0.0067 second.
#  Iter 1.  max mismatch = 1.4701436
#  Iter 2.  max mismatch = 0.3985662
#  Iter 3.  max mismatch = 0.0009131
#  Iter 4.  max mismatch = 0.0000008
#  Solution converged in 0.0122 second in 4 iterations
# Dynamic models initialized in 0.0051 second.
# report written to <case1_out.txt> in 0.0048 second.
# -> Time Domain Simulation: trapezoidal method, t=20.0 s
# Load on Bus 2-12 ramped up by 0.4 pu at t = 2                  |ETA:  0:00:01]
#  [100%|########################################################|Time: 0:00:03]
#  Time domain simulation finished in 3.3853 seconds.
# Simulation data dumped in 0.2230 second.
# cvxoptklu import error. Fall back to umfpack
# Found config file at /Users/hcui7/.andes/andes.conf.
# Loaded config file from /Users/hcui7/.andes/andes.conf.
# Input format guessed as dome.
# Parsing input file <case2.dm>
# Parsing include file <ieee28.dm>
# Imported model <vsc.VSC>.
# Imported model <vsc.VSC1_IE2>.
# Imported model <windturbine.WTG4DC>.
# Imported model <wind.ConstWind>.
# Parsing of include file <ieee28.dm> completed.
# Case file case2.dm parsed in 0.0319 second.
# -> Power flow study: NR method, non-flat start
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
# Power flow initialized in 0.0031 second.
#  Iter 1.  max mismatch = 1.4701436
#  Iter 2.  max mismatch = 0.3985662
#  Iter 3.  max mismatch = 0.0009131
#  Iter 4.  max mismatch = 0.0000008
#  Solution converged in 0.0185 second in 4 iterations
# Dynamic models initialized in 0.0074 second.
# report written to <case2_out.txt> in 0.0087 second.
# -> Time Domain Simulation: trapezoidal method, t=20.0 s
# Load on Bus 2-12 ramped up by 0.4 pu at t = 2                  |ETA:  0:00:01]
#  [100%|########################################################|Time: 0:00:04]
#  Time domain simulation finished in 4.6845 seconds.
# Simulation data dumped in 0.1708 second.
# cvxoptklu import error. Fall back to umfpack
# Found config file at /Users/hcui7/.andes/andes.conf.
# Loaded config file from /Users/hcui7/.andes/andes.conf.
# Input format guessed as dome.
# Parsing input file <case3.dm>
# Parsing include file <ieee28.dm>
# Imported model <vsc.VSC>.
# Imported model <vsc.VSC1_IE2>.
# Imported model <windturbine.WTG4DC>.
# Imported model <wind.ConstWind>.
# Parsing of include file <ieee28.dm> completed.
# Case file case3.dm parsed in 0.0335 second.
# -> Power flow study: NR method, non-flat start
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
# Power flow initialized in 0.0028 second.
#  Iter 1.  max mismatch = 1.4701436
#  Iter 2.  max mismatch = 0.3985662
#  Iter 3.  max mismatch = 0.0009131
#  Iter 4.  max mismatch = 0.0000008
#  Solution converged in 0.0189 second in 4 iterations
# Dynamic models initialized in 0.0069 second.
# report written to <case3_out.txt> in 0.0079 second.
# -> Time Domain Simulation: trapezoidal method, t=20.0 s
# Load on Bus 2-12 ramped up by 0.4 pu at t = 2                  |ETA:  0:00:01]
#  [100%|########################################################|Time: 0:00:08]
#  Time domain simulation finished in 8.2709 seconds.
# Simulation data dumped in 0.1883 second.
# cvxoptklu import error. Fall back to umfpack
# Found config file at /Users/hcui7/.andes/andes.conf.
# Loaded config file from /Users/hcui7/.andes/andes.conf.
# Input format guessed as dome.
# Parsing input file <case4.dm>
# Parsing include file <ieee28.dm>
# Imported model <vsc.VSC>.
# Imported model <vsc.VSC1_IE2>.
# Imported model <windturbine.WTG4DC>.
# Imported model <wind.ConstWind>.
# Parsing of include file <ieee28.dm> completed.
# Case file case4.dm parsed in 0.0295 second.
# -> Power flow study: NR method, non-flat start
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
# Power flow initialized in 0.0032 second.
#  Iter 1.  max mismatch = 1.4701436
#  Iter 2.  max mismatch = 0.3985662
#  Iter 3.  max mismatch = 0.0009131
#  Iter 4.  max mismatch = 0.0000008
#  Solution converged in 0.0181 second in 4 iterations
# Dynamic models initialized in 0.0064 second.
# report written to <case4_out.txt> in 0.0084 second.
# -> Time Domain Simulation: trapezoidal method, t=20.0 s
# Load on Bus 2-12 ramped up by 0.4 pu at t = 2                  |ETA:  0:00:01]
#  [100%|########################################################|Time: 0:00:09]
#  Time domain simulation finished in 9.1554 seconds.
# Simulation data dumped in 0.1830 second.
