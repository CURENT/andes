# %% [markdown]
# # Case Descriptions
#
# ## ROCOF based methods
#
# 0.4 pu load ramping on Bus 12 in Area 2
#
#  - _Case 1_: No inertia emulation at all
#  - _Case 2_: Power Sharing between areas (VSC 1 and 2 local inertia emulation enabled, VSC 2 dc droop enabled)
#  - _Case 3_: WTG inertia response (VSC 2 inertia emulation, WTGs IE enabled)
#  - _Case 4_: Area power sharing with WTG inertial response (VSC 1 and 2 inertia emulation enabled. Observe inadequate responses from WTGs)
#  - _Case 5_: Adequate inertial response from WTGs (additional frequency information from grid areas)
#
# Load Ramping in Area 2

# %%
with  open('case1.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm

ALTER, VSC1_IE2, REP, VSC 1, Ki, 0
ALTER, VSC1_IE2, REP, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, 0
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 0

ALTER, WTG4DC, REP, WTG4 1, Kdc, 0
ALTER, WTG4DC, REP, WTG4 2, Kdc, 0
""")

with  open('case2.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm

ALTER, VSC1_IE2, REP, VSC 1, Ki, 50
ALTER, VSC1_IE2, REP, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, 50
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 10

ALTER, WTG4DC, REP, WTG4 1, Kdc, 0
ALTER, WTG4DC, REP, WTG4 2, Kdc, 0
""")

with  open('case3.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm

ALTER, VSC1_IE2, REP, VSC 1, Ki, -0
ALTER, VSC1_IE2, MUL, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, 50
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 10

ALTER, WTG4DC, REP, WTG4 1, Kdc, 10
ALTER, WTG4DC, REP, WTG4 2, Kdc, 10
""")

with  open('case4.dm', 'w') as fid:
    fid.write("""# DOME format 1.0
INCLUDE, ieee28.dm

ALTER, VSC1_IE2, REP, VSC 1, Ki, 50
ALTER, VSC1_IE2, REP, VSC 1, Kdc, 0

ALTER, VSC1_IE2, REP, VSC 2, Ki, 50
ALTER, VSC1_IE2, REP, VSC 2, Kdc, 10

ALTER, WTG4DC, REP, WTG4 1, Kdc, 10
ALTER, WTG4DC, REP, WTG4 2, Kdc, 10
""")

# %%
# tds = {
#     'case': os.path.abspath('./case1.dm'),
#     'pert': 'load12_ramp.py',
#     }

# %matplotlib inline

import os

from matplotlib import pyplot

from andes.main import run
from andes.plot import main as andesplot
from andes.plot import read_dat, read_label, do_plot, add_plot

run(routine='s', case='case1.dm', pert='load212_ramp.py')
run(routine='s', case='case2.dm', pert='load212_ramp.py')
run(routine='s', case='case3.dm', pert='load212_ramp.py')
run(routine='s', case='case4.dm', pert='load212_ramp.py')

run(routine='t', case='case1.dm', pert='load212_ramp.py')
run(routine='t', case='case2.dm', pert='load212_ramp.py')
run(routine='t', case='case3.dm', pert='load212_ramp.py')
run(routine='t', case='case4.dm', pert='load212_ramp.py')
# Out:
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 03:27:32 PM
#
# Parsing input file case1.dm.
# Case file case1.dm parsed in 0.0432 second.
# System models initialized in 0.0309 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0554 second.
# Dynamic models initialized in 0.0144 second.
# Static report written to <case1_out.txt> in 0.0183 second.
#
# Eigenvalue Analysis:
# Report saved.
# System is small-signal stable in the initial neighbourhood.
# Analysis finished in 1.6757 seconds.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 03:27:34 PM
#
# Parsing input file case2.dm.
# Case file case2.dm parsed in 0.0556 second.
# System models initialized in 0.0282 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0617 second.
# Dynamic models initialized in 0.0078 second.
# Static report written to <case2_out.txt> in 0.0259 second.
#
# Eigenvalue Analysis:
# Report saved.
# System is small-signal stable in the initial neighbourhood.
# Analysis finished in 1.4820 seconds.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 03:27:36 PM
#
# Parsing input file case3.dm.
# Case file case3.dm parsed in 0.0293 second.
# System models initialized in 0.0427 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0822 second.
# Dynamic models initialized in 0.0205 second.
# Static report written to <case3_out.txt> in 0.0119 second.
#
# Eigenvalue Analysis:
# Report saved.
# System is small-signal stable in the initial neighbourhood.
# Analysis finished in 2.2944 seconds.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 03:27:39 PM
#
# Parsing input file case4.dm.
# Case file case4.dm parsed in 0.0531 second.
# System models initialized in 0.0562 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.1086 second.
# Dynamic models initialized in 0.0221 second.
# Static report written to <case4_out.txt> in 0.0571 second.
#
# Eigenvalue Analysis:
# Report saved.
# System is small-signal stable in the initial neighbourhood.
# Analysis finished in 1.9158 seconds.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 03:27:41 PM
#
# Parsing input file case1.dm.
# Case file case1.dm parsed in 0.0418 second.
# System models initialized in 0.0234 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0856 second.
# Dynamic models initialized in 0.0108 second.
# Static report written to <case1_out.txt> in 0.0299 second.
#
# Time Domain Simulation:
# Integration Method: Implicit Trapezoidal
# Simulation time: 20
#  (0%) Time = 0.0333s, step = 2, niter = 1
#  (5%) Time = 1.0333s, step = 62, niter = 1
# Load on Bus 2-12 ramped up by 0.4 pu at t = 2
#  (10%) Time = 2.0333s, step = 122, niter = 3
#  (15%) Time = 3.0333s, step = 182, niter = 2
#  (20%) Time = 4.0333s, step = 242, niter = 2
#  (25%) Time = 5.0333s, step = 302, niter = 2
#  (30%) Time = 6.0333s, step = 362, niter = 2
#  (35%) Time = 7.0333s, step = 422, niter = 2
#  (40%) Time = 8.0333s, step = 482, niter = 2
#  (45%) Time = 9.0333s, step = 542, niter = 2
#  (50%) Time = 10.0333s, step = 602, niter = 2
#  (55%) Time = 11.0333s, step = 662, niter = 2
#  (60%) Time = 12.0333s, step = 722, niter = 2
#  (65%) Time = 13.0333s, step = 782, niter = 2
#  (70%) Time = 14.0333s, step = 842, niter = 2
#  (75%) Time = 15.0333s, step = 902, niter = 2
#  (80%) Time = 16.0333s, step = 962, niter = 2
#  (85%) Time = 17.0333s, step = 1022, niter = 2
#  (90%) Time = 18.0333s, step = 1082, niter = 2
#  (95%) Time = 19.0333s, step = 1142, niter = 2
#  (100%) Time = 20.0000s, step = 1200, niter = 2
# Time domain simulation finished in 109.9558 seconds.
# Simulation data dumped in 0.3100 second.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 03:29:31 PM
#
# Parsing input file case2.dm.
# Case file case2.dm parsed in 0.0611 second.
# System models initialized in 0.0476 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0906 second.
# Dynamic models initialized in 0.0139 second.
# Static report written to <case2_out.txt> in 0.0270 second.
#
# Time Domain Simulation:
# Integration Method: Implicit Trapezoidal
# Simulation time: 20
#  (0%) Time = 0.0333s, step = 2, niter = 1
#  (5%) Time = 1.0333s, step = 62, niter = 1
# Load on Bus 2-12 ramped up by 0.4 pu at t = 2
#  (10%) Time = 2.0333s, step = 122, niter = 3
#  (15%) Time = 3.0333s, step = 182, niter = 3
#  (20%) Time = 4.0333s, step = 242, niter = 3
#  (25%) Time = 5.0333s, step = 302, niter = 3
#  (30%) Time = 6.0333s, step = 362, niter = 3
#  (35%) Time = 7.0333s, step = 422, niter = 3
#  (40%) Time = 8.0333s, step = 482, niter = 3
#  (45%) Time = 9.0333s, step = 542, niter = 2
#  (50%) Time = 10.0333s, step = 602, niter = 2
#  (55%) Time = 11.0333s, step = 662, niter = 2
#  (60%) Time = 12.0333s, step = 722, niter = 2
#  (65%) Time = 13.0333s, step = 782, niter = 2
#  (70%) Time = 14.0333s, step = 842, niter = 2
#  (75%) Time = 15.0333s, step = 902, niter = 2
#  (80%) Time = 16.0333s, step = 962, niter = 2
#  (85%) Time = 17.0333s, step = 1022, niter = 2
#  (90%) Time = 18.0333s, step = 1082, niter = 2
#  (95%) Time = 19.0333s, step = 1142, niter = 2
#  (100%) Time = 20.0000s, step = 1200, niter = 2
# Time domain simulation finished in 126.0252 seconds.
# Simulation data dumped in 0.1990 second.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 03:31:38 PM
#
# Parsing input file case3.dm.
# Case file case3.dm parsed in 0.0356 second.
# System models initialized in 0.0377 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0750 second.
# Dynamic models initialized in 0.0201 second.
# Static report written to <case3_out.txt> in 0.0227 second.
#
# Time Domain Simulation:
# Integration Method: Implicit Trapezoidal
# Simulation time: 20
#  (0%) Time = 0.0333s, step = 2, niter = 1
#  (5%) Time = 1.0333s, step = 62, niter = 1
# Load on Bus 2-12 ramped up by 0.4 pu at t = 2
#  (10%) Time = 2.0333s, step = 122, niter = 3
#  (15%) Time = 3.0333s, step = 182, niter = 6
#  (20%) Time = 4.0258s, step = 242, niter = 5
#  (25%) Time = 5.0258s, step = 302, niter = 5
#  (30%) Time = 6.0258s, step = 362, niter = 5
#  (35%) Time = 7.0258s, step = 422, niter = 4
#  (40%) Time = 8.0258s, step = 482, niter = 4
#  (45%) Time = 9.0258s, step = 542, niter = 3
#  (50%) Time = 10.0258s, step = 602, niter = 3
#  (55%) Time = 11.0258s, step = 662, niter = 2
#  (60%) Time = 12.0258s, step = 722, niter = 2
#  (65%) Time = 13.0258s, step = 782, niter = 2
#  (70%) Time = 14.0258s, step = 842, niter = 2
#  (75%) Time = 15.0258s, step = 902, niter = 2
#  (80%) Time = 16.0258s, step = 962, niter = 2
#  (85%) Time = 17.0258s, step = 1022, niter = 2
#  (90%) Time = 18.0258s, step = 1082, niter = 2
#  (95%) Time = 19.0258s, step = 1142, niter = 2
#  (100%) Time = 20.0000s, step = 1201, niter = 2
# Time domain simulation finished in 167.1767 seconds.
# Simulation data dumped in 0.3096 second.
#
# ANDES 2018.06.21-dev
# Copyright (C) 2015-2018 Hantao Cui
#
# ANDES comes with ABSOLUTELY NO WARRANTY
# Use this software AT YOUR OWN RISK
#
# Platform:    Linux
# Interpreter: Python 3.5.2
# Session:     07/12/2018 03:34:25 PM
#
# Parsing input file case4.dm.
# Case file case4.dm parsed in 0.0482 second.
# System models initialized in 0.0454 second.
#
# System contains 2 islands and 0 islanded buses.
# Each island has a slack bus correctly defined.
#
# Power Flow Analysis:
# Sparse Solver: KLU
# Solution Method: NR
# Flat-start: No
#
# Iter   1.  Max. Mismatch = 1.4701436
# Iter   2.  Max. Mismatch = 0.3985661
# Iter   3.  Max. Mismatch = 0.0009131
# Iter   4.  Max. Mismatch = 0.0000008
# Power flow converged in 0.0803 second.
# Dynamic models initialized in 0.0175 second.
# Static report written to <case4_out.txt> in 0.0256 second.
#
# Time Domain Simulation:
# Integration Method: Implicit Trapezoidal
# Simulation time: 20
#  (0%) Time = 0.0333s, step = 2, niter = 1
#  (5%) Time = 1.0333s, step = 62, niter = 1
# Load on Bus 2-12 ramped up by 0.4 pu at t = 2
#  (10%) Time = 2.0333s, step = 122, niter = 4
#  (15%) Time = 3.0333s, step = 182, niter = 5
#  (20%) Time = 4.0333s, step = 242, niter = 3
#  (25%) Time = 5.0333s, step = 302, niter = 4
#  (30%) Time = 6.0333s, step = 362, niter = 4
#  (35%) Time = 7.0333s, step = 422, niter = 3
#  (40%) Time = 8.0333s, step = 482, niter = 3
#  (45%) Time = 9.0333s, step = 542, niter = 2
#  (50%) Time = 10.0333s, step = 602, niter = 2
#  (55%) Time = 11.0333s, step = 662, niter = 2
#  (60%) Time = 12.0333s, step = 722, niter = 2
#  (65%) Time = 13.0333s, step = 782, niter = 2
#  (70%) Time = 14.0333s, step = 842, niter = 2
#  (75%) Time = 15.0333s, step = 902, niter = 2
#  (80%) Time = 16.0333s, step = 962, niter = 2
#  (85%) Time = 17.0333s, step = 1022, niter = 2
#  (90%) Time = 18.0333s, step = 1082, niter = 2
#  (95%) Time = 19.0333s, step = 1142, niter = 2
#  (100%) Time = 20.0000s, step = 1200, niter = 2
# Time domain simulation finished in 142.0763 seconds.
# Simulation data dumped in 0.2955 second.
