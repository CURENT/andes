# %%
# !andes prepare
# Out:
#     _           _         | Version 1.8.10.post0.dev0+g62037319
#    /_\  _ _  __| |___ ___ | Python 3.8.18 on Linux, 02/29/2024 01:23:16 PM
#   / _ \| ' \/ _` / -_|_-< |
#  /_/ \_\_||_\__,_\___/__/ | This program comes with ABSOLUTELY NO WARRANTY.
#
# > Loaded config from file "/home/aaliqureshi/.andes/andes.rc"
# Numerical code generation (quick mode) started...
# Generating code for 97 models on 8 processes.
# Saved generated pycode to "/home/aaliqureshi/.andes/pycode"
# > Loaded generated Python code in "/home/aaliqureshi/.andes/pycode".
# Generated numerical code for 97 models in 2.4606 seconds.

# %%
import andes
# andes.config_logger(10)

# %%
ss = andes.run("./SMIB_RL_Line.xlsx")
# Out:
# Working directory: "/home/aaliqureshi/andes/andes/cases/SMIB_Chow"
# > Loaded config from file "/home/aaliqureshi/.andes/andes.rc"
# > Reloaded generated Python code of module "pycode".
# Generated code for <PQ> is stale.
# Numerical code generation (rapid incremental mode) started...
# Generating code for 1 models on 8 processes.
# Saved generated pycode to "/home/aaliqureshi/.andes/pycode"
# > Reloaded generated Python code of module "pycode".
# Generated numerical code for 1 models in 0.1721 seconds.
# Parsing input file "./SMIB_RL_Line.xlsx"...
# Input file parsed in 0.0288 seconds.
# System internal structure set up in 0.0325 seconds.
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: Off
#    Sparse solver: KLU
#  Solution method: NR method
# Power flow initialized in 0.0041 seconds.
# 0: |F(x)| = 75.39822708
# ...

# %%
# ss.Fault.tc.v[0] = 6.02

# %%
ss.TDS.config.tf = 2

# %%
ss.TDS.config.tstep = 5e-5

# %%
ss.TDS.run()
# Out:
# -> Time Domain Simulation Summary:
# Sparse Solver: KLU
# Simulation time: 0.0-2 s.
# Fixed step size: h=0.05 ms. Shrink if not converged.
# The honest Newton method is being used. It will slow down the simulation.
# For speed up, set `honest=0` in TDS.config.
# Fixed time step is smaller than the estimated minimum.
# Initialization for dynamics completed in 0.0183 seconds.
# Initialization was successful.
#   0%|          | 0/100 [00:00<?, ?%/s]
# <Fault Fault_1>: Applying fault on Bus (idx=3) at t=1.0 sec.
# <Fault Fault_1>: Clearing fault on Bus (idx=3) at t=1.1 sec.
# Simulation to t=2.00 sec completed in 28.5577 seconds.
# Outputs to "SMIB_RL_Line_out.lst" and "SMIB_RL_Line_out.npz".
# Outputs written in 0.1615 seconds.
# True

# %%
# %matplotlib inline

# %%
fig, ax = ss.TDS.plotter.plot(ss.TDS.plotter.find('v')[0][0])

# %%
fig, ax = ss.TDS.plotter.plot(ss.TDS.plotter.find('v')[0][2])

# %%
fig, ax = ss.TDS.plotter.plot(ss.TDS.plotter.find('a')[0][6])

# %%
# ss.TDS.plt.plot(ss.GENCLS.omega, left=1.8, right=3)
ss.TDS.plt.plot(ss.GENCLS.omega)
# Out:
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:xlabel='Time [s]'>)

# %%
fig, ax = ss.TDS.plotter.plot(ss.TDS.plotter.find('idd')[0][0])

# %%
fig, ax = ss.TDS.plotter.plot(ss.TDS.plotter.find('Id')[0][0])

# %%
fig, ax = ss.TDS.plotter.plot(ss.TDS.plotter.find('iqq')[0][0])

# %%
fig, ax = ss.TDS.plotter.plot(ss.TDS.plotter.find('Iq')[0][0])

# %%
fig, ax = ss.TDS.plotter.plot(ss.TDS.plotter.find('idd')[0][1])

# %%
fig, ax = ss.TDS.plotter.plot(ss.TDS.plotter.find('iqq')[0][0])

# %%
fig, ax = ss.TDS.plotter.plot(ss.TDS.plotter.find('iqq')[0][1])

# %%
# ss.TDS.plt.plot(ss.Bus.a, left=1.8, right=2.1)
ss.TDS.plt.plot(ss.Bus.a)
# Out:
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:xlabel='Time [s]'>)

# %%
ss.GENCLS.omega
# Out:
# State: GENCLS.omega, a=[2 3], v=[0.99228314 1.        ], e=[-0.50982963  0.46894267]

# %%
ss.TDS.plt.find('idd')
# Out:
# ([3, 4], ['idd Line 1', 'idd Line 2'])

# %%
fig, ax = ss.TDS.plotter.plot(ss.TDS.plotter.find('idd')[0],savefig=True)

# %%
fig, ax = ss.TDS.plotter.plot(ss.TDS.plotter.find('iqq')[0],savefig=True)

# %%
fig, ax = ss.TDS.plotter.plot(ss.TDS.plotter.find('omega')[0][0],savefig=True)

# %%
fig, ax = ss.TDS.plotter.plot(ss.TDS.plotter.find('v')[0][0])

# %%
ss.dae.xy_name
# Out:
# ['iqq Line 1',
#  'iqq Line 2',
#  'idd Line 1',
#  'idd Line 2',
#  'delta GENCLS 1',
#  'delta GENCLS 2',
#  'omega GENCLS 1',
#  'omega GENCLS 2',
#  'a Bus 1',
#  'a Bus 2',
#  'a Bus 3',
#  'v Bus 1',
#  'v Bus 2',
#  'v Bus 3',
#  'q PV 1',
#  'q Slack 1',
#  'p Slack 1',
#  'Id GENCLS 1',
#  'Id GENCLS 2',
#  'Iq GENCLS 1',
#  'Iq GENCLS 2',
#  'vd GENCLS 1',
#  'vd GENCLS 2',
#  'vq GENCLS 1',
#  'vq GENCLS 2',
#  'tm GENCLS 1',
#  'tm GENCLS 2',
#  'te GENCLS 1',
#  'te GENCLS 2',
#  'vf GENCLS 1',
#  'vf GENCLS 2',
#  'XadIfd GENCLS 1',
#  'XadIfd GENCLS 2',
#  'Pe GENCLS 1',
#  'Pe GENCLS 2',
#  'Qe GENCLS 1',
#  'Qe GENCLS 2',
#  'psid GENCLS 1',
#  'psid GENCLS 2',
#  'psiq GENCLS 1',
#  'psiq GENCLS 2']

# %%
ss.dae.xy_name[17]
# Out:
# 'Id GENCLS 1'
